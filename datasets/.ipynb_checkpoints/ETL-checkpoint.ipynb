# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data

# %%
path = '.\WEOOct2022all.csv'

# %%
df_worldbank = pd.read_csv(path, sep=';', encoding='utf-8')

# %% [markdown]
# ## Transforming & Extracting Data

# %%
def tb_tratament(df: object, drop_columns: list) -> object:
    
    df = df.drop(drop_columns, axis=1)
    df = df.to_numpy()
    df = df.transpose()
    year = ['Year','2010','2011','2012','2013','2014','2015','2016','2017','2018', '2019','2020','2021',
        '2022','2023','2024','2025','2026','2027']
    year = np.array(year)
    df = np.hstack((year.reshape(19, 1), df))
    df = pd.DataFrame(df)
    return df

# %% [markdown]
#  ---------------------------------------------------------------

# %%
df_worldbank.head()
# Out:
#        Country                       Subject Descriptor  \
# 0  Afghanistan  Gross domestic product, constant prices
# 1  Afghanistan  Gross domestic product, constant prices
# 2  Afghanistan   Gross domestic product, current prices
# 3  Afghanistan   Gross domestic product, current prices
# 4  Afghanistan   Gross domestic product, current prices
#
#                                        Subject Notes  \
# 0  Expressed in billions of national currency uni...
# 1  Annual percentages of constant price GDP are y...
# 2  Expressed in billions of national currency uni...
# 3  Values are based upon GDP in national currency...
# 4  These data form the basis for the country weig...
#
#                                             Units     Scale  \
# 0                               National currency  Billions
# 1                                  Percent change       NaN
# 2                               National currency  Billions
# 3                                    U.S. dollars  Billions
# 4  Purchasing power parity, international dollars  Billions
#
#                        Country/Series-specific Notes 1980 1981 1982 1983  ...  \
# 0  Source: National Statistics Office Latest actu...  NaN  NaN  NaN  NaN  ...
# 1  See notes for:  Gross domestic product, consta...  NaN  NaN  NaN  NaN  ...
# 2  Source: National Statistics Office Latest actu...  NaN  NaN  NaN  NaN  ...
# 3  See notes for:  Gross domestic product, curren...  NaN  NaN  NaN  NaN  ...
# 4  See notes for:  Gross domestic product, curren...  NaN  NaN  NaN  NaN  ...
#
#        2019      2020 2021 2022 2023 2024 2025 2026 2027 Estimates Start After
# 0  1,319.90  1,288.87  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2020.0
# 1     3.912    -2.351  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2020.0
# 2  1,469.60  1,547.29  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2020.0
# 3    18.876    20.136  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2020.0
# 4    81.873    80.912  NaN  NaN  NaN  NaN  NaN  NaN  NaN                2020.0
#
# [5 rows x 55 columns]

# %%
df_worldbank.isna().sum()
# Out:
# Country                             0
# Subject Descriptor                  0
# Subject Notes                       0
# Units                               0
# Scale                            4704
# Country/Series-specific Notes     983
# 1980                             4738
# 1981                             4617
# 1982                             4574
# 1983                             4533
# 1984                             4507
# 1985                             4430
# 1986                             4383
# 1987                             4359
# 1988                             4270
# 1989                             4209
# 1990                             3721
# 1991                             3565
# 1992                             3181
# 1993                             2987
# 1994                             2860
# 1995                             2518
# 1996                             2378
# 1997                             2213
# 1998                             2041
# 1999                             1954
# 2000                             1542
# 2001                             1403
# 2002                             1305
# 2003                             1271
# 2004                             1195
# 2005                             1162
# 2006                             1155
# 2007                             1153
# 2008                             1142
# 2009                             1121
# 2010                             1109
# 2011                             1107
# 2012                             1091
# 2013                             1075
# 2014                             1049
# 2015                             1031
# 2016                             1029
# 2017                             1025
# 2018                             1028
# 2019                             1030
# 2020                             1031
# 2021                             1114
# 2022                             1181
# 2023                             1203
# 2024                             1287
# 2025                             1287
# 2026                             1287
# 2027                             1287
# Estimates Start After             983
# dtype: int64

# %%
df_worldbank = df_worldbank.drop(['1980','1981','1982','1983','1984','1985','1986','1987','1988','1989',
                           '1990','1991','1992','1993','1994','1995','1996','1997','1998','1999',
                           '2000','2001','2002','2003','2004','2005','2006','2007','2008','2009'], axis=1)

# %%
df_worldbank.head(50)
# Out:
#         Country                                 Subject Descriptor  \
# 0   Afghanistan            Gross domestic product, constant prices
# 1   Afghanistan            Gross domestic product, constant prices
# 2   Afghanistan             Gross domestic product, current prices
# 3   Afghanistan             Gross domestic product, current prices
# 4   Afghanistan             Gross domestic product, current prices
# 5   Afghanistan                   Gross domestic product, deflator
# 6   Afghanistan  Gross domestic product per capita, constant pr...
# 7   Afghanistan  Gross domestic product per capita, constant pr...
# 8   Afghanistan  Gross domestic product per capita, current prices
# 9   Afghanistan  Gross domestic product per capita, current prices
# 10  Afghanistan  Gross domestic product per capita, current prices
# 11  Afghanistan             Output gap in percent of potential GDP
# 12  Afghanistan  Gross domestic product based on purchasing-pow...
# 13  Afghanistan                        Implied PPP conversion rate
# 14  Afghanistan                                   Total investment
# 15  Afghanistan                             Gross national savings
# 16  Afghanistan                 Inflation, average consumer prices
# 17  Afghanistan                 Inflation, average consumer prices
# 18  Afghanistan           Inflation, end of period consumer prices
# 19  Afghanistan           Inflation, end of period consumer prices
# 20  Afghanistan            Volume of imports of goods and services
# 21  Afghanistan                         Volume of Imports of goods
# 22  Afghanistan            Volume of exports of goods and services
# 23  Afghanistan                         Volume of exports of goods
# 24  Afghanistan                                  Unemployment rate
# 25  Afghanistan                                         Employment
# 26  Afghanistan                                         Population
# 27  Afghanistan                         General government revenue
# 28  Afghanistan                         General government revenue
# 29  Afghanistan               General government total expenditure
# 30  Afghanistan               General government total expenditure
# 31  Afghanistan           General government net lending/borrowing
# 32  Afghanistan           General government net lending/borrowing
# 33  Afghanistan              General government structural balance
# 34  Afghanistan              General government structural balance
# 35  Afghanistan   General government primary net lending/borrowing
# 36  Afghanistan   General government primary net lending/borrowing
# 37  Afghanistan                        General government net debt
# 38  Afghanistan                        General government net debt
# 39  Afghanistan                      General government gross debt
# 40  Afghanistan                      General government gross debt
# 41  Afghanistan  Gross domestic product corresponding to fiscal...
# 42  Afghanistan                            Current account balance
# 43  Afghanistan                            Current account balance
# 44      Albania            Gross domestic product, constant prices
# 45      Albania            Gross domestic product, constant prices
# 46      Albania             Gross domestic product, current prices
# 47      Albania             Gross domestic product, current prices
# 48      Albania             Gross domestic product, current prices
# 49      Albania                   Gross domestic product, deflator
#
#                                         Subject Notes  \
# 0   Expressed in billions of national currency uni...
# 1   Annual percentages of constant price GDP are y...
# 2   Expressed in billions of national currency uni...
# 3   Values are based upon GDP in national currency...
# 4   These data form the basis for the country weig...
# 5   The GDP deflator is derived by dividing curren...
# 6   GDP is expressed in constant national currency...
# 7   GDP is expressed in constant international dol...
# 8   GDP is expressed in current national currency ...
# 9   GDP is expressed in current U.S. dollars per p...
# 10  Expressed in GDP in PPP dollars per person. Da...
# 11  Output gaps for advanced economies are calcula...
# 12  Expressed in percent of world GDP in PPP dolla...
# 13  Expressed in national currency per current int...
# 14  Expressed as a ratio of total investment in cu...
# 15  Expressed as a ratio of gross national savings...
# 16  Expressed in averages for the year, not end-of...
# 17  Annual percentages of average consumer prices ...
# 18  Expressed in end of the period, not annual ave...
# 19  Annual percentages of end of period consumer p...
# 20  Percent change of volume of imports refers to ...
# 21  Percent change of volume of imports of goods r...
# 22  Percent change of volume of exports refers to ...
# 23  Percent change of volume of exports of goods r...
# 24  Unemployment rate can be defined by either the...
# 25  Employment can be defined by either the nation...
# 26  For census purposes, the total population of t...
# 27  Revenue consists of taxes, social contribution...
# 28  Revenue consists of taxes, social contribution...
# 29  Total expenditure consists of total expense an...
# 30  Total expenditure consists of total expense an...
# 31  Net lending (+)/ borrowing (-) is calculated a...
# 32  Net lending (+)/ borrowing (-) is calculated a...
# 33  The structural budget balance refers to the ge...
# 34  The structural budget balance refers to the ge...
# 35  Primary net lending/borrowing is net lending (...
# 36  Primary net lending/borrowing is net lending (...
# 37  Net debt is calculated as gross debt minus fin...
# 38  Net debt is calculated as gross debt minus fin...
# 39  Gross debt consists of all liabilities that re...
# 40  Gross debt consists of all liabilities that re...
# 41  Gross domestic product corresponding to fiscal...
# 42  Current account is all transactions other than...
# 43  Current account is all transactions other than...
# 44  Expressed in billions of national currency uni...
# 45  Annual percentages of constant price GDP are y...
# 46  Expressed in billions of national currency uni...
# 47  Values are based upon GDP in national currency...
# 48  These data form the basis for the country weig...
# 49  The GDP deflator is derived by dividing curren...
#
#                                                 Units     Scale  \
# 0                                   National currency  Billions
# 1                                      Percent change       NaN
# 2                                   National currency  Billions
# 3                                        U.S. dollars  Billions
# 4      Purchasing power parity, international dollars  Billions
# 5                                               Index       NaN
# 6                                   National currency     Units
# 7   Purchasing power parity, 2017 international do...     Units
# 8                                   National currency     Units
# 9                                        U.S. dollars     Units
# 10     Purchasing power parity, international dollars     Units
# 11                           Percent of potential GDP       NaN
# 12                                            Percent       NaN
# 13  National currency per current international do...       NaN
# 14                                     Percent of GDP       NaN
# 15                                     Percent of GDP       NaN
# 16                                              Index       NaN
# 17                                     Percent change       NaN
# 18                                              Index       NaN
# 19                                     Percent change       NaN
# 20                                     Percent change       NaN
# 21                                     Percent change       NaN
# 22                                     Percent change       NaN
# 23                                     Percent change       NaN
# 24                       Percent of total labor force       NaN
# 25                                            Persons  Millions
# 26                                            Persons  Millions
# 27                                  National currency  Billions
# 28                                     Percent of GDP       NaN
# 29                                  National currency  Billions
# 30                                     Percent of GDP       NaN
# 31                                  National currency  Billions
# 32                                     Percent of GDP       NaN
# 33                                  National currency  Billions
# 34                           Percent of potential GDP       NaN
# 35                                  National currency  Billions
# 36                                     Percent of GDP       NaN
# 37                                  National currency  Billions
# 46  Source: IMF Staff Estimates. Official national...   1,239.65   1,300.62
# 47  See notes for:  Gross domestic product, curren...     11.937     12.899
# 48  See notes for:  Gross domestic product, curren...     28.331     29.655
# 49  See notes for:  Gross domestic product, consta...    184.141    188.404
#
#          2012       2013  ...       2019       2020      2021      2022  \
# 0    1,092.12   1,154.18  ...   1,319.90   1,288.87       NaN       NaN
# 1      13.968      5.683  ...      3.912     -2.351       NaN       NaN
# 2    1,033.59   1,116.83  ...   1,469.60   1,547.29       NaN       NaN
# 3      20.293      20.17  ...     18.876     20.136       NaN       NaN
# 4      59.945     63.784  ...     81.873     80.912       NaN       NaN
# 5      94.641     96.764  ...    111.341     120.05       NaN       NaN
# 6   42,225.02  43,169.34  ...  40,990.73  39,127.08       NaN       NaN
# 7    2,513.14   2,569.34  ...   2,439.68   2,328.76       NaN       NaN
# 8   39,962.17  41,772.32  ...  45,639.64  46,972.10       NaN       NaN
# 9     784.611    754.402  ...    586.204    611.268       NaN       NaN
# 10   2,317.69   2,385.71  ...   2,542.64   2,456.29       NaN       NaN
# 11        NaN        NaN  ...        NaN        NaN       NaN       NaN
# 12       0.06       0.06  ...       0.06      0.061       NaN       NaN
# 13     17.242     17.509  ...      17.95     19.123       NaN       NaN
# 14      25.34     23.093  ...     18.192     16.462       NaN       NaN
# 15     36.204     24.538  ...     29.897     27.619       NaN       NaN
# 16     90.717     97.417  ...    114.264    120.671       NaN       NaN
# 17      6.441      7.386  ...      2.302      5.607       NaN       NaN
# 18     94.687    101.543  ...      116.3      122.1       NaN       NaN
# 19      5.875      7.241  ...      2.773      4.987       NaN       NaN
# 20      30.54       3.61  ...     -7.473     -2.925       NaN       NaN
# 21     34.866      7.832  ...     -4.937     -2.844       NaN       NaN
# 22    -23.515    -37.604  ...     -3.838      0.534       NaN       NaN
# 23      4.546       9.76  ...      1.531    -16.606       NaN       NaN
# 24        NaN        NaN  ...        NaN        NaN       NaN       NaN
# 25        NaN        NaN  ...        NaN        NaN       NaN       NaN
# 26     25.864     26.736  ...       32.2     32.941       NaN       NaN
# 27    260.571    271.903  ...    395.923    397.564       NaN       NaN
# 28      25.21     24.346  ...     26.941     25.694       NaN       NaN
# 29    258.689     278.95  ...    411.473    432.266       NaN       NaN
# 30     25.028     24.977  ...     27.999     27.937       NaN       NaN
# 31      1.882     -7.047  ...     -15.55    -34.703       NaN       NaN
# 32      0.182     -0.631  ...     -1.058     -2.243       NaN       NaN
# 33        NaN        NaN  ...        NaN        NaN       NaN       NaN
# 34        NaN        NaN  ...        NaN        NaN       NaN       NaN
# 35       2.66     -6.075  ...    -14.971    -34.131       NaN       NaN
# 36      0.257     -0.544  ...     -1.019     -2.206       NaN       NaN
# 37        NaN        NaN  ...        NaN        NaN       NaN       NaN
# 38        NaN        NaN  ...        NaN        NaN       NaN       NaN
# 39     69.865     77.111  ...     90.092    114.461       NaN       NaN
# 40      6.759      6.904  ...       6.13      7.397       NaN       NaN
# 41       NaN       NaN       NaN       NaN       NaN                2020.0
# 42       NaN       NaN       NaN       NaN       NaN                2020.0
# 43       NaN       NaN       NaN       NaN       NaN                2020.0
# 44   935.388   965.321   996.211  1,030.08  1,065.11                2020.0
# 45       2.5       3.2       3.2       3.4       3.4                2020.0
# 46  2,176.66  2,287.47  2,403.26  2,530.79  2,664.39                2020.0
# 47    18.842    19.858    21.219    22.528    23.889                2020.0
# 48    54.338    57.254    60.184    63.415     66.84                2020.0
# 49   232.701   236.964    241.24   245.688   250.153                2020.0
#
# [50 rows x 25 columns]

# %%
tb_pib_percent = df_worldbank[(df_worldbank['Subject Descriptor'] == 
                               'Gross domestic product, constant prices') & (df_worldbank['Units'] == 'Percent change')]

# %%
tb_pib_percapita = df_worldbank[(df_worldbank['Subject Descriptor'] == 'Gross domestic product per capita, constant prices') 
                             & (df_worldbank['Subject Notes'] == 
                                'GDP is expressed in constant international dollars per person. Data are derived by dividing constant price purchasing-power parity (PPP) GDP by total population.')]

# %%
tb_pib_based_on_purchasing_power_parity = df_worldbank[df_worldbank['Subject Descriptor'] == 
                                                    'Gross domestic product based on purchasing-power-parity (PPP) share of world total']

# %%
tb_total_investments = df_worldbank[df_worldbank['Subject Descriptor'] == 'Total investment']

# %%
tb_inflation_average_consumer_prices = df_worldbank[df_worldbank['Subject Notes'] == 
                                                   'Annual percentages of average consumer prices are year-on-year changes.']

# %%
tb_unemployment_rate = df_worldbank[df_worldbank['Subject Descriptor'] == 'Unemployment rate']

# %%
tb_population = df_worldbank[df_worldbank['Subject Descriptor'] == 'Population']

# %%
tb_current_account_balance = df_worldbank[(df_worldbank['Subject Descriptor'] == 'Current account balance')
                                         & (df_worldbank['Scale'] == 'Billions')]

# %%
drop_columns = ['Subject Descriptor','Subject Notes','Units','Scale',
                'Country/Series-specific Notes','Estimates Start After']

tb_pib_percent = tb_tratament(tb_pib_percent, drop_columns)
tb_pib_percapita = tb_tratament(tb_pib_percapita, drop_columns)
tb_pib_based_on_purchasing_power_parity = tb_tratament(tb_pib_based_on_purchasing_power_parity, drop_columns)
tb_total_investments = tb_tratament(tb_total_investments, drop_columns)
tb_inflation_average_consumer_prices = tb_tratament(tb_inflation_average_consumer_prices, drop_columns)
tb_unemployment_rate = tb_tratament(tb_unemployment_rate, drop_columns)
tb_population = tb_tratament(tb_population, drop_columns)
tb_current_account_balance = tb_tratament(tb_current_account_balance, drop_columns)

# %% [markdown]
#  ---------------------------------------------------------------------------------------

# %% [markdown]
# ## Saving Data

# %%
tb_pib_percent.to_csv('tb_pib_percent.csv')
tb_pib_percapita.to_csv('tb_pib_percapita.csv')
tb_pib_based_on_purchasing_power_parity.to_csv('tb_pib_based_on_purchasing_power_parity.csv')
tb_total_investments.to_csv('tb_total_investments.csv')
tb_inflation_average_consumer_prices.to_csv('tb_inflation_average_consumer_prices.csv')
tb_unemployment_rate.to_csv('tb_unemployment_rate.csv')
tb_population.to_csv('tb_population.csv')
tb_current_account_balance.to_csv('tb_current_account_balance.csv')
